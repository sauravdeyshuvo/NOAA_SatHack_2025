# %%
import os
import glob
import json
import requests

import rasterio
from rasterio.errors import RasterioIOError
from rasterio.merge import merge
from shapely.geometry import box, mapping

# 0. SETTING PARAMETERS
lon_min, lon_max = -124.5, -114.0
lat_min, lat_max =   32.0,    42.0
geom = mapping(box(lon_min, lat_min, lon_max, lat_max))
date_range = "2020-08-15/2020-08-15"

out_root = r"D:\1Research\2025\NOAA_SatHack\data\sentinel_ca"
os.makedirs(out_root, exist_ok=True)

bands = ["B03", "B04", "B08", "B11"]
STAC_SEARCH = "https://earth-search.aws.element84.com/v0/search"

# 1. STAC SEARCH
payload = {
    "collections": ["sentinel-s2-l2a-cogs"],
    "intersects": geom,
    "datetime": date_range,
    "query": { "eo:cloud_cover": { "lt": 20 } },
    "limit": 100
}
resp = requests.post(STAC_SEARCH, json=payload)
resp.raise_for_status()
features = resp.json()["features"]
print(f"Discovered {len(features)} Sentinel-2 scenes")

# 2. DOWNLOAD LOOP WITH STREAM and FALLBACK
for feat in features:
    scene_id = feat["id"].replace(":", "_")
    scene_dir = os.path.join(out_root, scene_id)
    os.makedirs(scene_dir, exist_ok=True)

    for band in bands:
        href = feat["assets"][band]["href"]
        out_path = os.path.join(scene_dir, f"{scene_id}_{band}.tif")
        if os.path.exists(out_path):
            continue

        print(f"Retrieving {band} for {scene_id}")
        try:
            with rasterio.Env(CPL_VSIL_CURL_USE_HEAD="FALSE"):
                with rasterio.open(f"/vsicurl/{href}") as src:
                    arr = src.read(1)
                    profile = src.profile.copy()
            profile.update(driver="GTiff", compress="lzw")
            with rasterio.open(out_path, "w", **profile) as dst:
                dst.write(arr, 1)

        except (RasterioIOError, OSError) as e:
            print(f"  Stream error: {e}\n  Falling back to full download…")
            r = requests.get(href, stream=True)
            r.raise_for_status()
            with open(out_path, "wb") as f:
                for chunk in r.iter_content(chunk_size=1024*1024):
                    f.write(chunk)
# Out:
# Discovered 41 Sentinel-2 scenes
# Retrieving B03 for S2A_10SCF_20200815_0_L2A
# Retrieving B04 for S2A_10SCF_20200815_0_L2A
# Retrieving B08 for S2A_10SCF_20200815_0_L2A
# Retrieving B11 for S2A_10SCF_20200815_0_L2A
# Retrieving B03 for S2A_10SDF_20200815_0_L2A
# Retrieving B04 for S2A_10SDF_20200815_0_L2A
# Retrieving B08 for S2A_10SDF_20200815_0_L2A
# Retrieving B11 for S2A_10SDF_20200815_0_L2A
# Retrieving B03 for S2A_10SEF_20200815_0_L2A
# Retrieving B04 for S2A_10SEF_20200815_0_L2A
# Retrieving B08 for S2A_10SEF_20200815_0_L2A
# Retrieving B11 for S2A_10SEF_20200815_0_L2A
# Retrieving B03 for S2A_10SCG_20200815_0_L2A
# Retrieving B04 for S2A_10SCG_20200815_0_L2A
# Retrieving B08 for S2A_10SCG_20200815_0_L2A
# Retrieving B11 for S2A_10SCG_20200815_0_L2A
# Retrieving B03 for S2A_10SDG_20200815_1_L2A
# Retrieving B04 for S2A_10SDG_20200815_1_L2A
# Retrieving B08 for S2A_10SDG_20200815_1_L2A
# Retrieving B11 for S2A_10SDG_20200815_1_L2A
# Retrieving B03 for S2A_10SEG_20200815_1_L2A
# Retrieving B04 for S2A_10SEG_20200815_1_L2A
# Retrieving B08 for S2A_10SEG_20200815_1_L2A
# Retrieving B11 for S2A_10SEG_20200815_1_L2A
# Retrieving B03 for S2A_10SCH_20200815_1_L2A
# Retrieving B04 for S2A_10SCH_20200815_1_L2A
# Retrieving B08 for S2A_10SCH_20200815_1_L2A
# Retrieving B11 for S2A_10SCH_20200815_1_L2A
# Retrieving B03 for S2A_10SDG_20200815_0_L2A
# Retrieving B04 for S2A_10SDG_20200815_0_L2A
# Retrieving B08 for S2A_10SDG_20200815_0_L2A
# Retrieving B11 for S2A_10SDG_20200815_0_L2A
# Retrieving B03 for S2A_10SDH_20200815_1_L2A
# Retrieving B04 for S2A_10SDH_20200815_1_L2A
# Retrieving B08 for S2A_10SDH_20200815_1_L2A
# Retrieving B11 for S2A_10SDH_20200815_1_L2A
# Retrieving B03 for S2A_10SEG_20200815_0_L2A
# Retrieving B04 for S2A_10SEG_20200815_0_L2A
# Retrieving B08 for S2A_10SEG_20200815_0_L2A
# Retrieving B11 for S2A_10SEG_20200815_0_L2A
# Retrieving B03 for S2A_10SEH_20200815_1_L2A
# Retrieving B04 for S2A_10SEH_20200815_1_L2A
# Retrieving B08 for S2A_10SEH_20200815_1_L2A
# Retrieving B11 for S2A_10SEH_20200815_1_L2A
# Retrieving B03 for S2A_10SCH_20200815_0_L2A
# Retrieving B04 for S2A_10SCH_20200815_0_L2A
# Retrieving B08 for S2A_10SCH_20200815_0_L2A
# Retrieving B11 for S2A_10SCH_20200815_0_L2A
# Retrieving B03 for S2A_10SDH_20200815_0_L2A
# Retrieving B04 for S2A_10SDH_20200815_0_L2A
# Retrieving B08 for S2A_10SDH_20200815_0_L2A
# Retrieving B11 for S2A_10SDH_20200815_0_L2A
# Retrieving B03 for S2A_10SEH_20200815_0_L2A
# Retrieving B04 for S2A_10SEH_20200815_0_L2A
# Retrieving B08 for S2A_10SEH_20200815_0_L2A
# Retrieving B11 for S2A_10SEH_20200815_0_L2A
# Retrieving B03 for S2A_10SCJ_20200815_0_L2A
# Retrieving B04 for S2A_10SCJ_20200815_0_L2A
# Retrieving B08 for S2A_10SCJ_20200815_0_L2A
# Retrieving B11 for S2A_10SCJ_20200815_0_L2A
# Retrieving B03 for S2A_10SDJ_20200815_0_L2A
# Retrieving B04 for S2A_10SDJ_20200815_0_L2A
# Retrieving B08 for S2A_10SDJ_20200815_0_L2A
# Retrieving B11 for S2A_10SDJ_20200815_0_L2A
# Retrieving B03 for S2A_10SEJ_20200815_0_L2A
# Retrieving B04 for S2A_10SEJ_20200815_0_L2A
# Retrieving B08 for S2A_10SEJ_20200815_0_L2A
# Retrieving B11 for S2A_10SEJ_20200815_0_L2A
# Retrieving B03 for S2A_10TCK_20200815_0_L2A
# Retrieving B04 for S2A_10TCK_20200815_0_L2A
# Retrieving B08 for S2A_10TCK_20200815_0_L2A
# Retrieving B11 for S2A_10TCK_20200815_0_L2A
# Retrieving B03 for S2A_10TDK_20200815_0_L2A
# Retrieving B04 for S2A_10TDK_20200815_0_L2A
# Retrieving B08 for S2A_10TDK_20200815_0_L2A
# Retrieving B11 for S2A_10TDK_20200815_0_L2A
# Retrieving B03 for S2A_10TEK_20200815_0_L2A
# Retrieving B04 for S2A_10TEK_20200815_0_L2A
# Retrieving B08 for S2A_10TEK_20200815_0_L2A
# Retrieving B11 for S2A_10TEK_20200815_0_L2A
# Retrieving B03 for S2A_10TCL_20200815_0_L2A
# Retrieving B04 for S2A_10TCL_20200815_0_L2A
# Retrieving B08 for S2A_10TCL_20200815_0_L2A
# Retrieving B11 for S2A_10TCL_20200815_0_L2A
# Retrieving B03 for S2A_10TFK_20200815_0_L2A
# Retrieving B04 for S2A_10TFK_20200815_0_L2A
# Retrieving B08 for S2A_10TFK_20200815_0_L2A
# Retrieving B11 for S2A_10TFK_20200815_0_L2A
# Retrieving B03 for S2A_10TDL_20200815_0_L2A
# Retrieving B04 for S2A_10TDL_20200815_0_L2A
# Retrieving B08 for S2A_10TDL_20200815_0_L2A
# Retrieving B11 for S2A_10TDL_20200815_0_L2A
# Retrieving B03 for S2A_10TEL_20200815_0_L2A
# Retrieving B04 for S2A_10TEL_20200815_0_L2A
# Retrieving B08 for S2A_10TEL_20200815_0_L2A
# Retrieving B11 for S2A_10TEL_20200815_0_L2A
# Retrieving B03 for S2A_10TFL_20200815_0_L2A
# Retrieving B04 for S2A_10TFL_20200815_0_L2A
# Retrieving B08 for S2A_10TFL_20200815_0_L2A
# Retrieving B11 for S2A_10TFL_20200815_0_L2A
# Retrieving B03 for S2A_10TCM_20200815_0_L2A
# Retrieving B04 for S2A_10TCM_20200815_0_L2A
# Retrieving B08 for S2A_10TCM_20200815_0_L2A
# Retrieving B11 for S2A_10TCM_20200815_0_L2A
# Retrieving B03 for S2A_10TDM_20200815_0_L2A
# Retrieving B04 for S2A_10TDM_20200815_0_L2A
# Retrieving B08 for S2A_10TDM_20200815_0_L2A
# Retrieving B11 for S2A_10TDM_20200815_0_L2A
# Retrieving B03 for S2A_10TEM_20200815_0_L2A
# Retrieving B04 for S2A_10TEM_20200815_0_L2A
# Retrieving B08 for S2A_10TEM_20200815_0_L2A
# Retrieving B11 for S2A_10TEM_20200815_0_L2A
# Retrieving B03 for S2A_10TFM_20200815_0_L2A
# Retrieving B04 for S2A_10TFM_20200815_0_L2A
# Retrieving B08 for S2A_10TFM_20200815_0_L2A
# Retrieving B11 for S2A_10TFM_20200815_0_L2A
# Retrieving B03 for S2B_11SPR_20200815_0_L2A
# Retrieving B04 for S2B_11SPR_20200815_0_L2A
# Retrieving B08 for S2B_11SPR_20200815_0_L2A
# Retrieving B11 for S2B_11SPR_20200815_0_L2A
# Retrieving B03 for S2B_11SQR_20200815_0_L2A
# Retrieving B04 for S2B_11SQR_20200815_0_L2A
# Retrieving B08 for S2B_11SQR_20200815_0_L2A
# Retrieving B11 for S2B_11SQR_20200815_0_L2A
# Retrieving B03 for S2B_12STA_20200815_0_L2A
# Retrieving B04 for S2B_12STA_20200815_0_L2A
# Retrieving B08 for S2B_12STA_20200815_0_L2A
# Retrieving B11 for S2B_12STA_20200815_0_L2A
# Retrieving B03 for S2B_11SPS_20200815_0_L2A
# Retrieving B04 for S2B_11SPS_20200815_0_L2A
# Retrieving B08 for S2B_11SPS_20200815_0_L2A
# Retrieving B11 for S2B_11SPS_20200815_0_L2A
# Retrieving B03 for S2B_11SQS_20200815_0_L2A
# Retrieving B04 for S2B_11SQS_20200815_0_L2A
# Retrieving B08 for S2B_11SQS_20200815_0_L2A
# Retrieving B11 for S2B_11SQS_20200815_0_L2A
# Retrieving B03 for S2B_12STB_20200815_0_L2A
# Retrieving B04 for S2B_12STB_20200815_0_L2A
# Retrieving B08 for S2B_12STB_20200815_0_L2A
# Retrieving B11 for S2B_12STB_20200815_0_L2A
# Retrieving B03 for S2B_11SQT_20200815_0_L2A
# Retrieving B04 for S2B_11SQT_20200815_0_L2A
# Retrieving B08 for S2B_11SQT_20200815_0_L2A
# Retrieving B11 for S2B_11SQT_20200815_0_L2A
# Retrieving B03 for S2B_12STC_20200815_0_L2A
# Retrieving B04 for S2B_12STC_20200815_0_L2A
# Retrieving B08 for S2B_12STC_20200815_0_L2A
# Retrieving B11 for S2B_12STC_20200815_0_L2A
# Retrieving B03 for S2B_11SQU_20200815_0_L2A
# Retrieving B04 for S2B_11SQU_20200815_0_L2A
# Retrieving B08 for S2B_11SQU_20200815_0_L2A
# Retrieving B11 for S2B_11SQU_20200815_0_L2A
# Retrieving B03 for S2B_12STD_20200815_0_L2A
# Retrieving B04 for S2B_12STD_20200815_0_L2A
# Retrieving B08 for S2B_12STD_20200815_0_L2A
# Retrieving B11 for S2B_12STD_20200815_0_L2A
# Retrieving B03 for S2B_11SQV_20200815_0_L2A
# Retrieving B04 for S2B_11SQV_20200815_0_L2A
# Retrieving B08 for S2B_11SQV_20200815_0_L2A
# Retrieving B11 for S2B_11SQV_20200815_0_L2A
# Retrieving B03 for S2B_12STE_20200815_0_L2A
# Retrieving B04 for S2B_12STE_20200815_0_L2A
# Retrieving B08 for S2B_12STE_20200815_0_L2A
# Retrieving B11 for S2B_12STE_20200815_0_L2A
# Reference CRS for B03: PROJCS["WGS 84 / UTM zone 10N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-123],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_11SPR_20200815_0_L2A_B03.tif CRS=PROJCS["WGS 84 / UTM zone 11N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-117],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_11SPS_20200815_0_L2A_B03.tif CRS=PROJCS["WGS 84 / UTM zone 11N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-117],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_11SQR_20200815_0_L2A_B03.tif CRS=PROJCS["WGS 84 / UTM zone 11N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-117],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_11SQS_20200815_0_L2A_B03.tif CRS=PROJCS["WGS 84 / UTM zone 11N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-117],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_11SQT_20200815_0_L2A_B03.tif CRS=PROJCS["WGS 84 / UTM zone 11N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-117],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_11SQU_20200815_0_L2A_B03.tif CRS=PROJCS["WGS 84 / UTM zone 11N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-117],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_11SQV_20200815_0_L2A_B03.tif CRS=PROJCS["WGS 84 / UTM zone 11N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-117],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_12STA_20200815_0_L2A_B03.tif CRS=PROJCS["WGS 84 / UTM zone 12N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-111],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_12STB_20200815_0_L2A_B03.tif CRS=PROJCS["WGS 84 / UTM zone 12N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-111],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_12STC_20200815_0_L2A_B03.tif CRS=PROJCS["WGS 84 / UTM zone 12N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-111],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_12STD_20200815_0_L2A_B03.tif CRS=PROJCS["WGS 84 / UTM zone 12N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-111],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_12STE_20200815_0_L2A_B03.tif CRS=PROJCS["WGS 84 / UTM zone 12N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-111],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# Reference CRS for B04: PROJCS["WGS 84 / UTM zone 10N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-123],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_11SPR_20200815_0_L2A_B04.tif CRS=PROJCS["WGS 84 / UTM zone 11N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-117],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_11SPS_20200815_0_L2A_B04.tif CRS=PROJCS["WGS 84 / UTM zone 11N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-117],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_11SQR_20200815_0_L2A_B04.tif CRS=PROJCS["WGS 84 / UTM zone 11N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-117],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_11SQS_20200815_0_L2A_B04.tif CRS=PROJCS["WGS 84 / UTM zone 11N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-117],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_11SQT_20200815_0_L2A_B04.tif CRS=PROJCS["WGS 84 / UTM zone 11N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-117],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_11SQU_20200815_0_L2A_B04.tif CRS=PROJCS["WGS 84 / UTM zone 11N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-117],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_11SQV_20200815_0_L2A_B04.tif CRS=PROJCS["WGS 84 / UTM zone 11N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-117],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_12STA_20200815_0_L2A_B04.tif CRS=PROJCS["WGS 84 / UTM zone 12N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-111],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_12STB_20200815_0_L2A_B04.tif CRS=PROJCS["WGS 84 / UTM zone 12N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-111],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_12STC_20200815_0_L2A_B04.tif CRS=PROJCS["WGS 84 / UTM zone 12N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-111],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_12STD_20200815_0_L2A_B04.tif CRS=PROJCS["WGS 84 / UTM zone 12N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-111],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
#   Skipping S2B_12STE_20200815_0_L2A_B04.tif CRS=PROJCS["WGS 84 / UTM zone 12N",GEOGCS["WGS 84",DATUM["World Geodetic System 1984",SPHEROID["WGS 84",6378137,298.257223563]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",-111],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH]]
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[4], line 106
#     103     print(f"No matching-CRS files for {band}, skipping mosaic.")
#     104     continue
# --> 106 arr, transform = merge(srcs)
#     107 mosaics[band] = (arr[0].astype("float32"), transform, ref_crs)
#     108 for s in srcs:
#
# File ~\anaconda3\envs\wrf\lib\site-packages\rasterio\merge.py:483, in merge(sources, bounds, res, nodata, dtype, precision, indexes, output_count, resampling, method, target_aligned_pixels, mem_limit, use_highest_res, masked, dst_path, dst_kwds)
#     480         else:
#     481             region_mask = region == nodataval
# --> 483         data = src.read(
#     484             out_shape=(src_count, cw.height, cw.width),
#     485             indexes=indexes,
#     486             masked=True,
#     487             window=sw,
#     488             resampling=resampling,
#     489         )
#     491         copyto(
#     492             region,
#     493             data,
#    (...)
#     498             coff=cw.col_off,
#     499         )
#     501 if dst:
#
# File rasterio\\_io.pyx:650, in rasterio._io.DatasetReaderBase.read()
#
# MemoryError: Unable to allocate 115. MiB for an array with shape (1, 10980, 10980) and data type uint8
