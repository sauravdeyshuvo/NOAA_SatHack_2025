# %%
import os
import glob
import numpy as np
import rasterio
from rasterio.vrt import WarpedVRT
from rasterio.warp import calculate_default_transform, Resampling
from rasterio.merge import merge
import geopandas as gpd
import matplotlib.pyplot as plt
from rasterio.plot import plotting_extent

# 1) PATHS AND SETTINGS
band_dir      = r"D:\1Research\2025\NOAA_SatHack\NBR\sentinel2_california_postfire"
nbr_tile_dir  = r"D:\1Research\2025\NOAA_SatHack\NBR\nbr_tiles2"
os.makedirs(nbr_tile_dir, exist_ok=True)

mosaic_fp     = r"D:\1Research\2025\NOAA_SatHack\NBR\nbr_mosaic2_1km.tif"
county_shp    = r"D:\1Research\2025\NOAA_SatHack\cb_2018_us_county_500k"

target_crs    = "EPSG:3310"        
tile_res      = 10                  
mosaic_res    = (1000, 1000)       

# 2) HELPER TO COMPUTE ONE TILE’S NBR
def compute_nbr(nir_fp, swir_fp, out_fp):
    # Open a VRT for each band, reprojected on the fly
    with rasterio.open(nir_fp) as src_nir, rasterio.open(swir_fp) as src_swir:
        transform, width, height = calculate_default_transform(
            src_nir.crs, target_crs, src_nir.width, src_nir.height, *src_nir.bounds, resolution=tile_res
        )
        meta = src_nir.meta.copy()
        meta.update({
            "crs": target_crs,
            "transform": transform,
            "width": width,
            "height": height,
            "count": 1,
            "dtype": "float32",
            "nodata": np.nan
        })

        # Read reprojected arrays
        with WarpedVRT(src_nir, crs=target_crs,
                       transform=transform, width=width, height=height,
                       resampling=Resampling.bilinear) as vrt_nir, \
             WarpedVRT(src_swir, crs=target_crs,
                       transform=transform, width=width, height=height,
                       resampling=Resampling.bilinear) as vrt_swir:

            arr_nir  = vrt_nir.read(1).astype("float32")
            arr_swir = vrt_swir.read(1).astype("float32")

        # Compute NBR and write tile
        nbr = (arr_nir - arr_swir) / (arr_nir + arr_swir)
        with rasterio.open(out_fp, "w", **meta) as dst:
            dst.write(nbr, 1)
    print(f"Wrote NBR tile: {os.path.basename(out_fp)}")

# 3) RUN PER-TILE NBR PROCESSING
b08_files = sorted(glob.glob(os.path.join(band_dir, "*_B08.tif")))
b12_files = sorted(glob.glob(os.path.join(band_dir, "*_B12.tif")))

for b08, b12 in zip(b08_files, b12_files):
    tile_id = os.path.basename(b08).split("_B08")[0]
    out_fp  = os.path.join(nbr_tile_dir, f"{tile_id}_NBR.tif")
    if not os.path.exists(out_fp):
        compute_nbr(b08, b12, out_fp)
# Out:
# C:\Users\saura\AppData\Local\Temp\ipykernel_15020\3688350983.py:58: RuntimeWarning: invalid value encountered in divide
#   nbr = (arr_nir - arr_swir) / (arr_nir + arr_swir)
# Wrote NBR tile: S2A_MSIL2A_20200825T185921_R013_T10SEH_20200827T175112_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200825T185921_R013_T10SEJ_20200827T175110_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200825T185921_R013_T10TCL_20200827T175102_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200825T185921_R013_T10TCM_20200827T175047_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200825T185921_R013_T10TDK_20200827T175109_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200825T185921_R013_T10TDL_20200918T171843_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200825T185921_R013_T10TDM_20200909T084101_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200825T185921_R013_T10TEL_20200827T175101_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200825T185921_R013_T10TEM_20200918T171901_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200825T185921_R013_T10TFK_20200827T175057_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200825T185921_R013_T10TFL_20200827T175055_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200825T185921_R013_T10TFM_20200827T175059_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SKU_20200827T204629_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SKV_20200827T204634_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SLA_20200827T204726_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SLB_20200909T084309_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SLC_20200827T204629_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SLD_20200827T204631_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SLU_20200827T204751_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SLV_20200918T172513_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SMA_20200827T204747_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SMB_20200827T204755_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SMC_20200827T204820_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SMD_20200827T204634_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SMT_20200918T172524_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SMU_20200827T204816_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SMV_20200918T172527_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SNA_20200918T172529_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SNB_20200918T172527_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SNC_20200918T172532_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SND_20200827T204819_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SNR_20200827T204626_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SNS_20200827T204632_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SNT_20200827T204609_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SNU_20200827T204610_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SNV_20200827T204559_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SPA_20200827T204610_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SPB_20200827T204602_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SPC_20200827T204559_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SPC_20200827T204637_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SPD_20200827T204604_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SPD_20200827T204801_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SPV_20200827T204613_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11SQD_20200827T204812_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11TME_20200918T172707_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11TMF_20200827T204619_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11TMG_20200827T204611_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11TNE_20200827T204808_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11TNF_20200827T204755_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11TNG_20200909T084347_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11TPE_20200918T172807_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11TPF_20200827T204759_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11TPG_20200827T204843_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11TQE_20200827T204550_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11TQF_20200827T204601_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T11TQG_20200827T204607_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T12STJ_20200827T204743_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T12TTK_20200827T204528_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T12TTL_20200827T204527_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200826T182921_R027_T12TTM_20200827T204548_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200828T190921_R056_T10SCJ_20200907T112742_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200828T190921_R056_T10TCK_20200907T112740_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200828T190921_R056_T10TCL_20200907T112430_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200828T190921_R056_T10TCL_20200907T112746_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200828T190921_R056_T10TCM_20200907T112424_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200828T190921_R056_T10TDK_20200907T112753_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200828T190921_R056_T10TDL_20200907T112422_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200828T190921_R056_T10TDL_20200907T112753_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200828T190921_R056_T10TDM_20200907T112343_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T10SFF_20200907T140922_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T10SFG_20200907T140911_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T10SFH_20200907T140917_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T10SFJ_20200907T140908_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T10SGE_20200907T140850_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T10SGF_20200907T140927_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T10SGG_20200907T140858_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T10SGH_20200907T141047_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T10SGJ_20200907T140913_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T10TGK_20200907T140921_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T10TGL_20200907T140835_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T10TGL_20200907T140859_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T10TGM_20200907T140835_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11SKA_20200907T140905_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11SKB_20200907T141031_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11SKC_20200907T141029_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11SKD_20200907T140857_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11SKU_20200907T140851_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11SKV_20200907T140909_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11SLA_20200907T140902_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11SLB_20200907T140855_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11SLC_20200907T140924_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11SLD_20200907T141018_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11SLT_20200907T140844_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11SLU_20200907T140925_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11SLV_20200907T140851_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11SMA_20200907T140911_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11SMB_20200907T140911_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11SMC_20200907T140858_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11SMD_20200907T140850_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11SND_20200907T140915_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11TKE_20200907T140901_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11TKF_20200907T140836_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11TKG_20200907T140834_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11TLE_20200907T141029_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11TLG_20200907T141019_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11TME_20200907T140858_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11TMF_20200907T140903_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11TMG_20200907T140824_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11TNE_20200907T140903_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11TNF_20200907T140826_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200829T183921_R070_T11TNG_20200907T140823_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200830T180921_R084_T11SPS_20200907T165503_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200830T180921_R084_T11SQS_20200907T165503_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200830T180921_R084_T11SQT_20200907T165500_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200830T180921_R084_T11SQU_20200907T165511_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200830T180921_R084_T11SQV_20200907T165455_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200830T180921_R084_T12STB_20200907T165416_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200830T180921_R084_T12STC_20200907T165356_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200830T180921_R084_T12STD_20200907T165437_NBR.tif
# Wrote NBR tile: S2A_MSIL2A_20200830T180921_R084_T12STE_20200907T165454_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T10SFE_20200827T145543_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T10SFF_20200827T145539_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T10SFG_20200827T145324_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T10SFJ_20200827T145655_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T10SGE_20200918T171825_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T10SGF_20200918T171824_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T10SGG_20200918T171828_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T10SGH_20200827T145610_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T10SGJ_20200918T171837_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T10TGK_20200827T145605_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T10TGL_20200827T145620_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T11SKA_20200827T145316_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T11SKB_20200918T172506_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T11SKC_20200827T145317_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T11SKC_20200827T145639_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T11SKD_20200918T172507_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T11SKU_20200827T145316_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T11SKV_20200827T145317_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T11SLD_20200827T145519_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T11SLU_20200827T145312_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T11SLV_20200827T145313_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T11SMA_20200827T145317_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T11SMB_20200827T145314_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T11SMB_20200827T145535_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T11SMC_20200827T145645_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T11SMD_20200918T172516_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T11TKE_20200918T172626_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T11TKF_20200827T145630_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T11TLE_20200918T172635_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T11TLF_20200918T172640_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T11TLG_20200918T172641_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T11TME_20200918T172707_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T11TMF_20200918T172708_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200824T183919_R070_T11TNE_20200827T145626_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200825T180919_R084_T11SPS_20200827T175531_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200825T180919_R084_T11SQU_20200827T175530_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200825T180919_R084_T12STB_20200827T175511_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T10SDJ_20200907T081305_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T10SEH_20200907T081040_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T10SEJ_20200907T081042_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T10SFF_20200907T081043_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T10SFG_20200907T081042_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T10SFH_20200907T081029_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T10SFJ_20200907T081044_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T10SGE_20200907T081032_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T10SGF_20200907T081033_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T10SGG_20200907T081327_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T10SGH_20200907T081037_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T10SGJ_20200907T081040_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T10TEK_20200907T081035_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T10TEL_20200907T081033_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T10TEM_20200907T081035_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T10TFK_20200907T081038_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T10TFL_20200907T081036_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T10TFM_20200907T081037_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T10TGK_20200907T080524_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T10TGL_20200907T080952_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T10TGM_20200907T081036_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T11SKA_20200907T080527_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T11SKB_20200907T081030_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T11SKC_20200907T081055_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T11SKD_20200907T080951_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T11TKE_20200907T080939_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T11TKF_20200907T080527_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T11TKG_20200907T081033_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T11TLE_20200907T081029_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T11TLF_20200907T081006_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200827T184919_R113_T11TLG_20200907T081025_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SMR_20200907T112937_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SMS_20200907T113004_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SMT_20200907T113004_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SNA_20200907T112959_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SNB_20200907T113000_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SNC_20200907T113001_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SNS_20200907T112951_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SNT_20200907T112947_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SNU_20200907T112943_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SNV_20200907T112942_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SPA_20200907T113012_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SPB_20200907T113010_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SPC_20200907T112938_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SPC_20200907T113412_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SPD_20200907T113407_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SPS_20200907T112919_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SPU_20200907T113023_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SQA_20200907T113027_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SQB_20200907T112919_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SQC_20200907T113413_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SQD_20200907T113407_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SQS_20200907T112926_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SQT_20200907T112923_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SQU_20200907T112941_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11SQV_20201027T091421_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11TPE_20200907T113412_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11TPF_20200907T113416_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11TPG_20200907T113410_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T11TQG_20200907T113415_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T12STB_20200907T112929_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T12STC_20200907T112925_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T12STD_20200907T112933_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T12STE_20200907T112919_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T12STF_20200907T112934_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T12STG_20201027T091418_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T12STH_20200907T113408_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T12STJ_20200907T113412_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200828T181919_R127_T12TTM_20200907T113408_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200830T185919_R013_T10SCG_20200907T164912_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200830T185919_R013_T10SCH_20200907T164859_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200830T185919_R013_T10SCJ_20200907T164910_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200830T185919_R013_T10SDJ_20200907T164858_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200830T185919_R013_T10SEH_20200907T164909_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200830T185919_R013_T10SEJ_20200907T164907_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200830T185919_R013_T10TCK_20200907T164855_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200830T185919_R013_T10TCL_20200907T164900_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200830T185919_R013_T10TCM_20200907T164912_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200830T185919_R013_T10TDL_20200907T164902_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200830T185919_R013_T10TDM_20200907T164906_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200830T185919_R013_T10TEL_20200907T164824_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200830T185919_R013_T10TEM_20200907T164903_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200830T185919_R013_T10TFL_20200907T164813_NBR.tif
# Wrote NBR tile: S2B_MSIL2A_20200830T185919_R013_T10TFM_20200907T164808_NBR.tif

# %%
# 4) MOSAIC NBR TILES AT 1 KM USING SUM & COUNT TO COMPUTE AVERAGE
# Gather tile filepaths and open sources
nbr_tiles = glob.glob(os.path.join(nbr_tile_dir, "*_NBR.tif"))
srcs = [rasterio.open(fp) for fp in nbr_tiles]

# 1) mosaic of sums
sum_mosaic, trans = merge(srcs, res=mosaic_res, method="sum")

# 2) mosaic of counts
count_mosaic, _ = merge(srcs, res=mosaic_res, method="count")

# 3) average 
avg_mosaic = np.where(count_mosaic > 0,
                      sum_mosaic / count_mosaic,
                      np.nan)
avg_band   = np.squeeze(avg_mosaic)  

# Close inputs
for src in srcs:
    src.close()

# 4) write out the averaged mosaic
profile = srcs[0].profile.copy()
profile.update({
    "height": avg_band.shape[0],
    "width":  avg_band.shape[1],
    "transform": trans,
    "crs": target_crs,
    "count": 1,
    "dtype": "float32",
    "nodata": np.nan
})

with rasterio.open(mosaic_fp, "w", **profile) as dst:
    dst.write(avg_band, 1)

print("Wrote averaged 1 km NBR mosaic:", mosaic_fp)
# Out:
# Wrote averaged 1 km NBR mosaic: D:\1Research\2025\NOAA_SatHack\NBR\nbr_mosaic2_1km.tif

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
from rasterio.vrt import WarpedVRT
from rasterio.plot import plotting_extent

# 5. PLOT THE MOSAIC WITH LAT/LON AXES
# Load and filter California counties, reproject to WGS84
counties = gpd.read_file(county_shp)
ca_counties = counties[counties["STATEFP"] == "06"].to_crs("EPSG:4326")

with rasterio.open(mosaic_fp) as src:
    # Create a virtual raster reprojected to EPSG:4326
    with WarpedVRT(src, crs="EPSG:4326") as vrt:
        arr = vrt.read(1)
        extent = plotting_extent(vrt)  

fig, ax = plt.subplots(figsize=(12, 9))

# Show the reprojected data
im = ax.imshow(
    arr,
    cmap="RdYlGn",
    vmin=-1, vmax=1,
    extent=extent,
    origin="upper",
    interpolation="none"
)

# Plot county boundaries in lon/lat
ca_counties.boundary.plot(
    ax=ax, edgecolor="black", linewidth=0.5
)

# Set titles and labels
ax.set_title("Post-Fire Normalized Burn Ratio – California", fontsize=14)
ax.set_xlabel("Longitude", fontsize=12)
ax.set_ylabel("Latitude", fontsize=12)

# Ticks as degrees
ax.xaxis.set_major_formatter(mticker.FormatStrFormatter("%.1f°"))
ax.yaxis.set_major_formatter(mticker.FormatStrFormatter("%.1f°"))

# Add grid
ax.grid(True, linestyle="--", linewidth=0.4, color="white", alpha=0.7)

# Colorbar
cbar = plt.colorbar(im, ax=ax, fraction=0.036, pad=0.04)
cbar.set_label("NBR Value", fontsize=12)

plt.savefig('post_fire.png', dpi = 300, bbox_inches = 'tight')
plt.show()
